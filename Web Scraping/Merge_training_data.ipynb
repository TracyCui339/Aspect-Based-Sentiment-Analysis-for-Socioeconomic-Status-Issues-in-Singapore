# %%
import pandas as pd

df1 = pd.read_csv('reddit_training_data.csv')
df2 = pd.read_csv('hardware_zone_training_data.csv')

# %%
merged_df = pd.concat([df1, df2],)
merged_df
# Out:
#       in that sense, it's possible to say that my generation has a much better $T$ than our elders, if i compare how things are now for my family, and how they used to be  \
# 0                                   access to education
# 1                                                     1
# 2     >the da will soon make public a plan to turn n...
# 3                                   access to education
# 4                                                     1
# ...                                                 ...
# 9011                                                NaN
# 9012                                                NaN
# 9013                                                NaN
# 9014                                                NaN
# 9015                                                NaN
#
# ...

# %%
merged_df.to_csv('reddit_hwz_training_data.csv', index=False)
